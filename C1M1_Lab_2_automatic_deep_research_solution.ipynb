# %%
from crewai import Agent, Task, Crew
import os
os.environ["CREWAI_TESTING"] = "true"
from utils import get_openai_api_key

# set the OpenAI model (gpt-4o-mini)
# os.environ["MODEL"] = "gpt-4o-mini"
# set up the OpenAI API key 
os.environ["OPENAI_API_KEY"] = get_openai_api_key()
# Out:
# Using Custom API Base: https://api.deepseek.com
# Using Model: deepseek-v4-flash

# %%
# import the tools
from crewai_tools import EXASearchTool, ScrapeWebsiteTool
from utils import get_exa_api_key

# set the exa API key
os.environ["EXA_API_KEY"] = get_exa_api_key()

### START CODE HERE ###

# Create the EXASearchTool instance
exa_search_tool = EXASearchTool(base_url=os.getenv("EXA_BASE_URL"))
# Create the ScrapeWebsiteTool instance
scrape_website_tool = ScrapeWebsiteTool()

### END CODE HERE ###
# Out:
# Using Custom API Base: https://api.deepseek.com
# Using Model: deepseek-v4-flash

# %%
# define the research planner agent
research_planner = Agent(
    role="Research Planner",
    goal="Analyze queries and break them down into smaller, specific research topics.",
    backstory=(
         "You are a research strategist who excels at breaking down complex questions "
         "into manageable research components. You identify what needs to be researched "
         "and create clear research objectives."
    ),
    verbose=True, # set to True to see detailed agent actions
    max_rpm=150,
    max_iter=15
)

# %%
researcher = Agent(
    role="Internet Researcher",
    goal="Research thoroughly all assigned topics",
    ### START CODE HERE ###
    backstory=(
        "You are a skilled researcher with experience in online investigation "
        "and data collection. You know how to find reliable sources, extract relevant information, "
        "and always verify facts across multiple sources to avoid misinformation or hallucination. "
        "You never invent facts and always trace information to its origin."
    ),
    # add the 2 tool instances you created
    tools=[exa_search_tool, scrape_website_tool],
    ### END CODE HERE ###
    verbose=True,
    max_rpm=150,
    max_iter=15
)

fact_checker = Agent(
    role="Fact Checker",
    goal=(
        "Verify data for accuracy, identify inconsistencies, "
        "and flag potential misinformation"
    ),
    ### START CODE HERE ###
    backstory=(
        "You are a quality assurance specialist with expertise in fact-checking "
        "and identifying misinformation and hallucinations. You cross-reference information, "
        "spot inconsistencies, and ensure all data meets high accuracy standards. You rigorously"
        "check for hallucinated or invented content and require that all facts be supported"
        "by evidence."
    ),
    tools=[exa_search_tool, scrape_website_tool],
    ### END CODE HERE ###
    verbose=True,
    max_rpm=150,
    max_iter=15
)

report_writer = Agent(
    role="Report Writer",
    goal="Write clear, concise, and well-structured reports based on gathered information",
    ### START CODE HERE ###
    backstory=(
         "You are an expert writer who specializes in creating clear, well-structured "
        "research reports. You synthesize complex information into readable formats and "
        "always include proper citations and sources."
    ),
    ### END CODE HERE ###
    verbose=True,max_rpm=150,
    max_iter=15
)

# %%
# define the create research plan task
create_research_plan_task = Task(
    description=(
        "Based on the user's query, break it down into specific topics and key questions, "
        "and create a focused research plan."
        "The user's query is: {user_query}"
    ),
    expected_output=(
        "A research plan with main research topics to investigate, "
        "key questions for each topic, and success criteria for the research."
        ),
    agent=research_planner,
)

# %%
# define the gather research data task
gather_research_data_task = Task(
    description=(
        "Using the research plan, collect information on all identified topics. "
        "Cite all sources used."
    ),
    ### START CODE HERE ###
    expected_output=(
        "Comprehensive research data including: information for each"
        "research topic, and citations used along with source credibility notes"
    ),
    agent=researcher,
    ### END CODE HERE ###
)

#define the verify information quality task
verify_information_quality_task = Task(
    description=(
        "Review all collected research. Identify any conflicting information, "
        "potential misinformation, or gaps that need addressing."
    ),
    ### START CODE HERE ###
    expected_output=(
        "A report with all the original data you got plus any "
        "verified facts vs. questionable information, make sure this is as comprehensive "
        "as possible for final report generation"
    ),
    agent=fact_checker,
    ### END CODE HERE ###
)

# define the write final report task
write_final_report_task = Task(
    description=(
        "Create a comprehensive report that answers the original query using all verified research data. "
        "Structure it with clear sections, include citations, and provide actionable insights."
    ),
    ### START CODE HERE ###
    expected_output=(
        "A final research report containing: executive summary, detailed "
        "findings that answer the user query, supporting evidence and analysis, complete "
        "source citations."
    ),
    agent=report_writer,
    ### END CODE HERE ###
)

# %%
# create the crew with the defined agents and tasks
crew = Crew(
    ### START CODE HERE ###
    agents=[research_planner, researcher, fact_checker, report_writer],
    tasks=[create_research_plan_task, gather_research_data_task, verify_information_quality_task, write_final_report_task],
    ### 
)

# %%
### START CODE HERE ###

# Write your query, which will be used as input for the tasks.
user_query = "Evaluate the top five emerging AI tools for automating competitive market analysis, including their features, limitations, costs, and ideal use cases for a mid-sized marketing firm."

### END CODE HERE ###

# %%
result = crew.kickoff(
    inputs={
        "user_query": user_query,
    }
)
# Out:
# /Users/taozh/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/pydantic/main.py:250: UserWarning: method callbacks cannot be serialized and will prevent checkpointing. Use a module-level named function instead.
#   validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Planner                                                                                        │
# │                                                                                                                 │
# │  Task: Based on the user's query, break it down into specific topics and key questions, and create a focused    │
# │  research plan.The user's query is: Evaluate the top five emerging AI tools for automating competitive market   │
# │  analysis, including their features, limitations, costs, and ideal use cases for a mid-sized marketing firm.    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ERROR:root:OpenAI API call failed: Error code: 400 - {'error': {'message': 'The supported API model names are deepseek-v4-pro or deepseek-v4-flash, but you passed gpt-4o-mini.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_request_error'}}
# ERROR:root:OpenAI API call failed: Error code: 400 - {'error': {'message': 'The supported API model names are deepseek-v4-pro or deepseek-v4-flash, but you passed gpt-4o-mini.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_request_error'}}
# [CrewAIEventsBus] Warning: Event pairing mismatch. 'llm_call_failed' closed 'agent_execution_started' (expected
# 'llm_call_started')
# An unknown error occurred. Please check the details below.
# Error details: Error code: 400 - {'error': {'message': 'The supported API model names are deepseek-v4-pro or deepseek-v4-flash, but you passed gpt-4o-mini.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_request_error'}}
# An unknown error occurred. Please check the details below.
# Error details: Error code: 400 - {'error': {'message': 'The supported API model names are deepseek-v4-pro or deepseek-v4-flash, but you passed gpt-4o-mini.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_request_error'}}
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Planner                                                                                        │
# │                                                                                                                 │
# │  Task: Based on the user's query, break it down into specific topics and key questions, and create a focused    │
# │  research plan.The user's query is: Evaluate the top five emerging AI tools for automating competitive market   │
# │  analysis, including their features, limitations, costs, and ideal use cases for a mid-sized marketing firm.    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ERROR:root:OpenAI API call failed: Error code: 400 - {'error': {'message': 'The supported API model names are deepseek-v4-pro or deepseek-v4-flash, but you passed gpt-4o-mini.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_request_error'}}
# ERROR:root:OpenAI API call failed: Error code: 400 - {'error': {'message': 'The supported API model names are deepseek-v4-pro or deepseek-v4-flash, but you passed gpt-4o-mini.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_request_error'}}
# [CrewAIEventsBus] Warning: Event pairing mismatch. 'llm_call_failed' closed 'agent_execution_started' (expected
# 'llm_call_started')
# An unknown error occurred. Please check the details below.
# Error details: Error code: 400 - {'error': {'message': 'The supported API model names are deepseek-v4-pro or deepseek-v4-flash, but you passed gpt-4o-mini.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_request_error'}}
# An unknown error occurred. Please check the details below.
# Error details: Error code: 400 - {'error': {'message': 'The supported API model names are deepseek-v4-pro or deepseek-v4-flash, but you passed gpt-4o-mini.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_request_error'}}
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Planner                                                                                        │
# │                                                                                                                 │
# │  Task: Based on the user's query, break it down into specific topics and key questions, and create a focused    │
# │  research plan.The user's query is: Evaluate the top five emerging AI tools for automating competitive market   │
# │  analysis, including their features, limitations, costs, and ideal use cases for a mid-sized marketing firm.    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ERROR:root:OpenAI API call failed: Error code: 400 - {'error': {'message': 'The supported API model names are deepseek-v4-pro or deepseek-v4-flash, but you passed gpt-4o-mini.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_request_error'}}
# ERROR:root:OpenAI API call failed: Error code: 400 - {'error': {'message': 'The supported API model names are deepseek-v4-pro or deepseek-v4-flash, but you passed gpt-4o-mini.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_request_error'}}
# [CrewAIEventsBus] Warning: Event pairing mismatch. 'llm_call_failed' closed 'agent_execution_started' (expected
# 'llm_call_started')
# An unknown error occurred. Please check the details below.
# Error details: Error code: 400 - {'error': {'message': 'The supported API model names are deepseek-v4-pro or deepseek-v4-flash, but you passed gpt-4o-mini.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_request_error'}}
# An unknown error occurred. Please check the details below.
# Error details: Error code: 400 - {'error': {'message': 'The supported API model names are deepseek-v4-pro or deepseek-v4-flash, but you passed gpt-4o-mini.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_request_error'}}
# [CrewAIEventsBus] Warning: Event pairing mismatch. 'agent_execution_error' closed 'task_started' (expected
# 'agent_execution_started')
# [CrewAIEventsBus] Warning: Event pairing mismatch. 'task_failed' closed 'crew_kickoff_started' (expected
# 'task_started')
# [CrewAIEventsBus] Warning: Ending event 'crew_kickoff_failed' emitted with empty scope stack. Missing starting
# event?
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 result = crew.kickoff(
#       2     inputs={
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/crew.py:956, in Crew.kickoff(self, inputs, input_files, from_checkpoint)
#     955 if self.process == Process.sequential:
# --> 956     result = self._run_sequential_process()
#     957 elif self.process == Process.hierarchical:
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/crew.py:1399, in Crew._run_sequential_process(self)
#    1398 """Executes tasks sequentially and returns the final output."""
# -> 1399 return self._execute_tasks(self.tasks)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/crew.py:1496, in Crew._execute_tasks(self, tasks, start_index, was_replayed)
#    1495 context = self._get_context(task, task_outputs)
# -> 1496 task_output = task.execute_sync(
#    1497     agent=exec_data.agent,
#    1498     context=context,
#    1499     tools=exec_data.tools,
#    1500 )
#    1501 task_outputs.append(task_output)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/task.py:581, in Task.execute_sync(self, agent, context, tools)
#     580 self.start_time = datetime.datetime.now()
# --> 581 return self._execute_core(agent, context, tools)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/task.py:878, in Task._execute_core(self, agent, context, tools)
#     877     crewai_event_bus.emit(self, TaskFailedEvent(error=str(e), task=self))
# --> 878     raise e  # Re-raise the exception after emitting the event
#     879 finally:
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/task.py:785, in Task._execute_core(self, agent, context, tools)
#     782     crewai_event_bus.emit(
#     783         self, TaskStartedEvent(context=context, task=self)
#     784     )
# --> 785 result = agent.execute_task(
#     786     task=self,
#     787     context=context,
#     788     tools=tools,
#     789 )
#     791 self._post_agent_execution(agent)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agent/core.py:794, in Agent.execute_task(self, task, context, tools)
#     793 except Exception as e:
# --> 794     result = self._handle_execution_error(e, task, context, tools)
#     796 return self._finalize_task_execution(task, result)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agent/core.py:704, in Agent._handle_execution_error(self, e, task, context, tools)
#     703 self._check_execution_error(e, task)
# --> 704 return self.execute_task(task, context, tools)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agent/core.py:794, in Agent.execute_task(self, task, context, tools)
#     793 except Exception as e:
# --> 794     result = self._handle_execution_error(e, task, context, tools)
#     796 return self._finalize_task_execution(task, result)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agent/core.py:704, in Agent._handle_execution_error(self, e, task, context, tools)
#     703 self._check_execution_error(e, task)
# --> 704 return self.execute_task(task, context, tools)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agent/core.py:794, in Agent.execute_task(self, task, context, tools)
#     793 except Exception as e:
# --> 794     result = self._handle_execution_error(e, task, context, tools)
#     796 return self._finalize_task_execution(task, result)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agent/core.py:703, in Agent._handle_execution_error(self, e, task, context, tools)
#     692 """Handle execution errors with retry logic (sync path).
#     693
#     694 Args:
#    (...)    701     Result from retried execution.
#     702 """
# --> 703 self._check_execution_error(e, task)
#     704 return self.execute_task(task, context, tools)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agent/core.py:683, in Agent._check_execution_error(self, e, task)
#     675 crewai_event_bus.emit(
#     676     self,
#     677     event=AgentExecutionErrorEvent(
#    (...)    681     ),
#     682 )
# --> 683 raise e
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agent/core.py:781, in Agent.execute_task(self, task, context, tools)
#     780     else:
# --> 781         result = self._execute_without_timeout(task_prompt, task)
#     783 except TimeoutError as e:
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agent/core.py:848, in Agent._execute_without_timeout(self, task_prompt, task)
#     844     raise RuntimeError("Agent executor is not initialized.")
#     846 result = cast(
#     847     dict[str, Any],
# --> 848     self.agent_executor.invoke(
#     849         {
#     850             "input": task_prompt,
#     851             "tool_names": self.agent_executor.tools_names,
#     852             "tools": self.agent_executor.tools_description,
#     853             "ask_for_human_input": task.human_input,
#     854         }
#     855     ),
#     856 )
#     857 return result["output"]
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agents/crew_agent_executor.py:214, in CrewAgentExecutor.invoke(self, inputs)
#     213 try:
# --> 214     formatted_answer = self._invoke_loop()
#     215 except AssertionError:
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agents/crew_agent_executor.py:311, in CrewAgentExecutor._invoke_loop(self)
#     309     return self._invoke_loop_native_tools()
# --> 311 return self._invoke_loop_react()
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agents/crew_agent_executor.py:437, in CrewAgentExecutor._invoke_loop_react(self)
#     436     handle_unknown_error(PRINTER, e, verbose=self.agent.verbose)
# --> 437     raise e
#     438 finally:
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agents/crew_agent_executor.py:339, in CrewAgentExecutor._invoke_loop_react(self)
#     337 enforce_rpm_limit(self.request_within_rpm_limit)
# --> 339 answer = get_llm_response(
#     340     llm=cast("BaseLLM", self.llm),
#     341     messages=self.messages,
#     342     callbacks=self.callbacks,
#     343     printer=PRINTER,
#     344     from_task=self.task,
#     345     from_agent=self.agent,
#     346     response_model=self.response_model,
#     347     executor_context=self,
#     348     verbose=self.agent.verbose,
#     349 )
#     350 if self.response_model is not None:
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/utilities/agent_utils.py:473, in get_llm_response(llm, messages, callbacks, printer, tools, available_functions, from_task, from_agent, response_model, executor_context, verbose)
#     472 except Exception as e:
# --> 473     raise e
#     475 return _validate_and_finalize_llm_response(
#     476     answer, executor_context, printer, verbose=verbose
#     477 )
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/utilities/agent_utils.py:463, in get_llm_response(llm, messages, callbacks, printer, tools, available_functions, from_task, from_agent, response_model, executor_context, verbose)
#     462 try:
# --> 463     answer = llm.call(
#     464         messages,
#     465         tools=tools,
#     466         callbacks=callbacks,
#     467         available_functions=available_functions,
#     468         from_task=from_task,
#     469         from_agent=from_agent,
#     470         response_model=response_model,
#     471     )
#     472 except Exception as e:
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/llms/providers/openai/completion.py:443, in OpenAICompletion.call(self, messages, tools, callbacks, available_functions, from_task, from_agent, response_model)
#     434         return self._call_responses(
#     435             messages=formatted_messages,
#     436             tools=tools,
#    (...)    440             response_model=response_model,
#     441         )
# --> 443     return self._call_completions(
#     444         messages=formatted_messages,
#     445         tools=tools,
#     446         available_functions=available_functions,
#     447         from_task=from_task,
#     448         from_agent=from_agent,
#     449         response_model=response_model,
#     450     )
#     452 except Exception as e:
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/llms/providers/openai/completion.py:483, in OpenAICompletion._call_completions(self, messages, tools, available_functions, from_task, from_agent, response_model)
#     475     return self._handle_streaming_completion(
#     476         params=completion_params,
#     477         available_functions=available_functions,
#    (...)    480         response_model=response_model,
#     481     )
# --> 483 return self._handle_completion(
#     484     params=completion_params,
#     485     available_functions=available_functions,
#     486     from_task=from_task,
#     487     from_agent=from_agent,
#     488     response_model=response_model,
#     489 )
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/llms/providers/openai/completion.py:1745, in OpenAICompletion._handle_completion(self, params, available_functions, from_task, from_agent, response_model)
#    1742     self._emit_call_failed_event(
#    1743         error=error_msg, from_task=from_task, from_agent=from_agent
#    1744     )
# -> 1745     raise e from e
#    1747 return content
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/llms/providers/openai/completion.py:1636, in OpenAICompletion._handle_completion(self, params, available_functions, from_task, from_agent, response_model)
#    1634         return parsed_object
# -> 1636 response: ChatCompletion = self._get_sync_client().chat.completions.create(
#    1637     **params
#    1638 )
#    1640 usage = self._extract_openai_token_usage(response)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/openai/resources/chat/completions/completions.py:1211, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1210 validate_response_format(response_format)
# -> 1211 return self._post(
#    1212     "/chat/completions",
#    1213     body=maybe_transform(
#    1214         {
#    1215             "messages": messages,
#    1216             "model": model,
#    1217             "audio": audio,
#    1218             "frequency_penalty": frequency_penalty,
#    1219             "function_call": function_call,
#    1220             "functions": functions,
#    1221             "logit_bias": logit_bias,
#    1222             "logprobs": logprobs,
#    1223             "max_completion_tokens": max_completion_tokens,
#    1224             "max_tokens": max_tokens,
#    1225             "metadata": metadata,
#    1226             "modalities": modalities,
#    1227             "n": n,
#    1228             "parallel_tool_calls": parallel_tool_calls,
#    1229             "prediction": prediction,
#    1230             "presence_penalty": presence_penalty,
#    1231             "prompt_cache_key": prompt_cache_key,
#    1232             "prompt_cache_retention": prompt_cache_retention,
#    1233             "reasoning_effort": reasoning_effort,
#    1234             "response_format": response_format,
#    1235             "safety_identifier": safety_identifier,
#    1236             "seed": seed,
#    1237             "service_tier": service_tier,
#    1238             "stop": stop,
#    1239             "store": store,
#    1240             "stream": stream,
#    1241             "stream_options": stream_options,
#    1242             "temperature": temperature,
#    1243             "tool_choice": tool_choice,
#    1244             "tools": tools,
#    1245             "top_logprobs": top_logprobs,
#    1246             "top_p": top_p,
#    1247             "user": user,
#    1248             "verbosity": verbosity,
#    1249             "web_search_options": web_search_options,
#    1250         },
#    1251         completion_create_params.CompletionCreateParamsStreaming
#    1252         if stream
#    1253         else completion_create_params.CompletionCreateParamsNonStreaming,
#    1254     ),
#    1255     options=make_request_options(
#    1256         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1257     ),
#    1258     cast_to=ChatCompletion,
#    1259     stream=stream or False,
#    1260     stream_cls=Stream[ChatCompletionChunk],
#    1261 )
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/openai/_base_client.py:1297, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1294 opts = FinalRequestOptions.construct(
#    1295     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1296 )
# -> 1297 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/openai/_base_client.py:1070, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1069     log.debug("Re-raising status error")
# -> 1070     raise self._make_status_error_from_response(err.response) from None
#    1072 break
#
# BadRequestError: Error code: 400 - {'error': {'message': 'The supported API model names are deepseek-v4-pro or deepseek-v4-flash, but you passed gpt-4o-mini.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_request_error'}}
#
# The above exception was the direct cause of the following exception:
#
# BadRequestError                           Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 result = crew.kickoff(
#       2     inputs={
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/crew.py:956, in Crew.kickoff(self, inputs, input_files, from_checkpoint)
#     955 if self.process == Process.sequential:
# --> 956     result = self._run_sequential_process()
#     957 elif self.process == Process.hierarchical:
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/crew.py:1399, in Crew._run_sequential_process(self)
#    1398 """Executes tasks sequentially and returns the final output."""
# -> 1399 return self._execute_tasks(self.tasks)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/crew.py:1496, in Crew._execute_tasks(self, tasks, start_index, was_replayed)
#    1495 context = self._get_context(task, task_outputs)
# -> 1496 task_output = task.execute_sync(
#    1497     agent=exec_data.agent,
#    1498     context=context,
#    1499     tools=exec_data.tools,
#    1500 )
#    1501 task_outputs.append(task_output)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/task.py:581, in Task.execute_sync(self, agent, context, tools)
#     580 self.start_time = datetime.datetime.now()
# --> 581 return self._execute_core(agent, context, tools)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/task.py:878, in Task._execute_core(self, agent, context, tools)
#     877     crewai_event_bus.emit(self, TaskFailedEvent(error=str(e), task=self))
# --> 878     raise e  # Re-raise the exception after emitting the event
#     879 finally:
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/task.py:785, in Task._execute_core(self, agent, context, tools)
#     782     crewai_event_bus.emit(
#     783         self, TaskStartedEvent(context=context, task=self)
#     784     )
# --> 785 result = agent.execute_task(
#     786     task=self,
#     787     context=context,
#     788     tools=tools,
#     789 )
#     791 self._post_agent_execution(agent)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agent/core.py:794, in Agent.execute_task(self, task, context, tools)
#     793 except Exception as e:
# --> 794     result = self._handle_execution_error(e, task, context, tools)
#     796 return self._finalize_task_execution(task, result)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agent/core.py:704, in Agent._handle_execution_error(self, e, task, context, tools)
#     703 self._check_execution_error(e, task)
# --> 704 return self.execute_task(task, context, tools)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agent/core.py:794, in Agent.execute_task(self, task, context, tools)
#     793 except Exception as e:
# --> 794     result = self._handle_execution_error(e, task, context, tools)
#     796 return self._finalize_task_execution(task, result)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agent/core.py:704, in Agent._handle_execution_error(self, e, task, context, tools)
#     703 self._check_execution_error(e, task)
# --> 704 return self.execute_task(task, context, tools)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agent/core.py:794, in Agent.execute_task(self, task, context, tools)
#     793 except Exception as e:
# --> 794     result = self._handle_execution_error(e, task, context, tools)
#     796 return self._finalize_task_execution(task, result)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agent/core.py:703, in Agent._handle_execution_error(self, e, task, context, tools)
#     692 """Handle execution errors with retry logic (sync path).
#     693
#     694 Args:
#    (...)    701     Result from retried execution.
#     702 """
# --> 703 self._check_execution_error(e, task)
#     704 return self.execute_task(task, context, tools)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agent/core.py:683, in Agent._check_execution_error(self, e, task)
#     675 crewai_event_bus.emit(
#     676     self,
#     677     event=AgentExecutionErrorEvent(
#    (...)    681     ),
#     682 )
# --> 683 raise e
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agent/core.py:781, in Agent.execute_task(self, task, context, tools)
#     780     else:
# --> 781         result = self._execute_without_timeout(task_prompt, task)
#     783 except TimeoutError as e:
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agent/core.py:848, in Agent._execute_without_timeout(self, task_prompt, task)
#     844     raise RuntimeError("Agent executor is not initialized.")
#     846 result = cast(
#     847     dict[str, Any],
# --> 848     self.agent_executor.invoke(
#     849         {
#     850             "input": task_prompt,
#     851             "tool_names": self.agent_executor.tools_names,
#     852             "tools": self.agent_executor.tools_description,
#     853             "ask_for_human_input": task.human_input,
#     854         }
#     855     ),
#     856 )
#     857 return result["output"]
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agents/crew_agent_executor.py:214, in CrewAgentExecutor.invoke(self, inputs)
#     213 try:
# --> 214     formatted_answer = self._invoke_loop()
#     215 except AssertionError:
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agents/crew_agent_executor.py:311, in CrewAgentExecutor._invoke_loop(self)
#     309     return self._invoke_loop_native_tools()
# --> 311 return self._invoke_loop_react()
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agents/crew_agent_executor.py:437, in CrewAgentExecutor._invoke_loop_react(self)
#     436     handle_unknown_error(PRINTER, e, verbose=self.agent.verbose)
# --> 437     raise e
#     438 finally:
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agents/crew_agent_executor.py:339, in CrewAgentExecutor._invoke_loop_react(self)
#     337 enforce_rpm_limit(self.request_within_rpm_limit)
# --> 339 answer = get_llm_response(
#     340     llm=cast("BaseLLM", self.llm),
#     341     messages=self.messages,
#     342     callbacks=self.callbacks,
#     343     printer=PRINTER,
#     344     from_task=self.task,
#     345     from_agent=self.agent,
#     346     response_model=self.response_model,
#     347     executor_context=self,
#     348     verbose=self.agent.verbose,
#     349 )
#     350 if self.response_model is not None:
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/utilities/agent_utils.py:473, in get_llm_response(llm, messages, callbacks, printer, tools, available_functions, from_task, from_agent, response_model, executor_context, verbose)
#     472 except Exception as e:
# --> 473     raise e
#     475 return _validate_and_finalize_llm_response(
#     476     answer, executor_context, printer, verbose=verbose
#     477 )
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/utilities/agent_utils.py:463, in get_llm_response(llm, messages, callbacks, printer, tools, available_functions, from_task, from_agent, response_model, executor_context, verbose)
#     462 try:
# --> 463     answer = llm.call(
#     464         messages,
#     465         tools=tools,
#     466         callbacks=callbacks,
#     467         available_functions=available_functions,
#     468         from_task=from_task,
#     469         from_agent=from_agent,
#     470         response_model=response_model,
#     471     )
#     472 except Exception as e:
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/llms/providers/openai/completion.py:443, in OpenAICompletion.call(self, messages, tools, callbacks, available_functions, from_task, from_agent, response_model)
#     434         return self._call_responses(
#     435             messages=formatted_messages,
#     436             tools=tools,
#    (...)    440             response_model=response_model,
#     441         )
# --> 443     return self._call_completions(
#     444         messages=formatted_messages,
#     445         tools=tools,
#     446         available_functions=available_functions,
#     447         from_task=from_task,
#     448         from_agent=from_agent,
#     449         response_model=response_model,
#     450     )
#     452 except Exception as e:
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/llms/providers/openai/completion.py:483, in OpenAICompletion._call_completions(self, messages, tools, available_functions, from_task, from_agent, response_model)
#     475     return self._handle_streaming_completion(
#     476         params=completion_params,
#     477         available_functions=available_functions,
#    (...)    480         response_model=response_model,
#     481     )
# --> 483 return self._handle_completion(
#     484     params=completion_params,
#     485     available_functions=available_functions,
#     486     from_task=from_task,
#     487     from_agent=from_agent,
#     488     response_model=response_model,
#     489 )
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/llms/providers/openai/completion.py:1745, in OpenAICompletion._handle_completion(self, params, available_functions, from_task, from_agent, response_model)
#    1742     self._emit_call_failed_event(
#    1743         error=error_msg, from_task=from_task, from_agent=from_agent
#    1744     )
# -> 1745     raise e from e
#    1747 return content
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/llms/providers/openai/completion.py:1636, in OpenAICompletion._handle_completion(self, params, available_functions, from_task, from_agent, response_model)
#    1634         return parsed_object
# -> 1636 response: ChatCompletion = self._get_sync_client().chat.completions.create(
#    1637     **params
#    1638 )
#    1640 usage = self._extract_openai_token_usage(response)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/openai/resources/chat/completions/completions.py:1211, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1210 validate_response_format(response_format)
# -> 1211 return self._post(
#    1212     "/chat/completions",
#    1213     body=maybe_transform(
#    1214         {
#    1215             "messages": messages,
#    1216             "model": model,
#    1217             "audio": audio,
#    1218             "frequency_penalty": frequency_penalty,
#    1219             "function_call": function_call,
#    1220             "functions": functions,
#    1221             "logit_bias": logit_bias,
#    1222             "logprobs": logprobs,
#    1223             "max_completion_tokens": max_completion_tokens,
#    1224             "max_tokens": max_tokens,
#    1225             "metadata": metadata,
#    1226             "modalities": modalities,
#    1227             "n": n,
#    1228             "parallel_tool_calls": parallel_tool_calls,
#    1229             "prediction": prediction,
#    1230             "presence_penalty": presence_penalty,
#    1231             "prompt_cache_key": prompt_cache_key,
#    1232             "prompt_cache_retention": prompt_cache_retention,
#    1233             "reasoning_effort": reasoning_effort,
#    1234             "response_format": response_format,
#    1235             "safety_identifier": safety_identifier,
#    1236             "seed": seed,
#    1237             "service_tier": service_tier,
#    1238             "stop": stop,
#    1239             "store": store,
#    1240             "stream": stream,
#    1241             "stream_options": stream_options,
#    1242             "temperature": temperature,
#    1243             "tool_choice": tool_choice,
#    1244             "tools": tools,
#    1245             "top_logprobs": top_logprobs,
#    1246             "top_p": top_p,
#    1247             "user": user,
#    1248             "verbosity": verbosity,
#    1249             "web_search_options": web_search_options,
#    1250         },
#    1251         completion_create_params.CompletionCreateParamsStreaming
#    1252         if stream
#    1253         else completion_create_params.CompletionCreateParamsNonStreaming,
#    1254     ),
#    1255     options=make_request_options(
#    1256         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1257     ),
#    1258     cast_to=ChatCompletion,
#    1259     stream=stream or False,
#    1260     stream_cls=Stream[ChatCompletionChunk],
#    1261 )
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/openai/_base_client.py:1297, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1294 opts = FinalRequestOptions.construct(
#    1295     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1296 )
# -> 1297 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/openai/_base_client.py:1070, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1069     log.debug("Re-raising status error")
# -> 1070     raise self._make_status_error_from_response(err.response) from None
#    1072 break
#
# BadRequestError: Error code: 400 - {'error': {'message': 'The supported API model names are deepseek-v4-pro or deepseek-v4-flash, but you passed gpt-4o-mini.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_request_error'}}
#
# The above exception was the direct cause of the following exception:
#
# BadRequestError                           Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 result = crew.kickoff(
#       2     inputs={
#       3         "user_query": user_query,
#       4     }
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/crew.py:956, in Crew.kickoff(self, inputs, input_files, from_checkpoint)
#     953 inputs = prepare_kickoff(self, inputs, input_files)
#     955 if self.process == Process.sequential:
# --> 956     result = self._run_sequential_process()
#     957 elif self.process == Process.hierarchical:
#     958     result = self._run_hierarchical_process()
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/crew.py:1399, in Crew._run_sequential_process(self)
#    1397 def _run_sequential_process(self) -> CrewOutput:
#    1398     """Executes tasks sequentially and returns the final output."""
# -> 1399     return self._execute_tasks(self.tasks)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/crew.py:1496, in Crew._execute_tasks(self, tasks, start_index, was_replayed)
#    1493     futures.clear()
#    1495 context = self._get_context(task, task_outputs)
# -> 1496 task_output = task.execute_sync(
#    1497     agent=exec_data.agent,
#    1498     context=context,
#    1499     tools=exec_data.tools,
#    1500 )
#    1501 task_outputs.append(task_output)
#    1502 self._process_task_result(task, task_output)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/task.py:581, in Task.execute_sync(self, agent, context, tools)
#     579 """Execute the task synchronously."""
#     580 self.start_time = datetime.datetime.now()
# --> 581 return self._execute_core(agent, context, tools)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/task.py:878, in Task._execute_core(self, agent, context, tools)
#     876     self.end_time = datetime.datetime.now()
#     877     crewai_event_bus.emit(self, TaskFailedEvent(error=str(e), task=self))
# --> 878     raise e  # Re-raise the exception after emitting the event
#     879 finally:
#     880     clear_task_files(self.id)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/task.py:785, in Task._execute_core(self, agent, context, tools)
#     781 if not (agent.agent_executor and agent.agent_executor._resuming):
#     782     crewai_event_bus.emit(
#     783         self, TaskStartedEvent(context=context, task=self)
#     784     )
# --> 785 result = agent.execute_task(
#     786     task=self,
#     787     context=context,
#     788     tools=tools,
#     789 )
#     791 self._post_agent_execution(agent)
#     793 if isinstance(result, BaseModel):
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agent/core.py:794, in Agent.execute_task(self, task, context, tools)
#     792     raise e
#     793 except Exception as e:
# --> 794     result = self._handle_execution_error(e, task, context, tools)
#     796 return self._finalize_task_execution(task, result)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agent/core.py:704, in Agent._handle_execution_error(self, e, task, context, tools)
#     692 """Handle execution errors with retry logic (sync path).
#     693
#     694 Args:
#    (...)    701     Result from retried execution.
#     702 """
#     703 self._check_execution_error(e, task)
# --> 704 return self.execute_task(task, context, tools)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agent/core.py:794, in Agent.execute_task(self, task, context, tools)
#     792     raise e
#     793 except Exception as e:
# --> 794     result = self._handle_execution_error(e, task, context, tools)
#     796 return self._finalize_task_execution(task, result)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agent/core.py:704, in Agent._handle_execution_error(self, e, task, context, tools)
#     692 """Handle execution errors with retry logic (sync path).
#     693
#     694 Args:
#    (...)    701     Result from retried execution.
#     702 """
#     703 self._check_execution_error(e, task)
# --> 704 return self.execute_task(task, context, tools)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agent/core.py:794, in Agent.execute_task(self, task, context, tools)
#     792     raise e
#     793 except Exception as e:
# --> 794     result = self._handle_execution_error(e, task, context, tools)
#     796 return self._finalize_task_execution(task, result)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agent/core.py:703, in Agent._handle_execution_error(self, e, task, context, tools)
#     685 def _handle_execution_error(
#     686     self,
#     687     e: Exception,
#    (...)    690     tools: list[BaseTool] | None,
#     691 ) -> Any:
#     692     """Handle execution errors with retry logic (sync path).
#     693
#     694     Args:
#    (...)    701         Result from retried execution.
#     702     """
# --> 703     self._check_execution_error(e, task)
#     704     return self.execute_task(task, context, tools)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agent/core.py:683, in Agent._check_execution_error(self, e, task)
#     674 if self._times_executed > self.max_retry_limit:
#     675     crewai_event_bus.emit(
#     676         self,
#     677         event=AgentExecutionErrorEvent(
#    (...)    681         ),
#     682     )
# --> 683     raise e
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agent/core.py:781, in Agent.execute_task(self, task, context, tools)
#     777         result = self._execute_with_timeout(
#     778             task_prompt, task, self.max_execution_time
#     779         )
#     780     else:
# --> 781         result = self._execute_without_timeout(task_prompt, task)
#     783 except TimeoutError as e:
#     784     crewai_event_bus.emit(
#     785         self,
#     786         event=AgentExecutionErrorEvent(
#    (...)    790         ),
#     791     )
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agent/core.py:848, in Agent._execute_without_timeout(self, task_prompt, task)
#     843 if not self.agent_executor:
#     844     raise RuntimeError("Agent executor is not initialized.")
#     846 result = cast(
#     847     dict[str, Any],
# --> 848     self.agent_executor.invoke(
#     849         {
#     850             "input": task_prompt,
#     851             "tool_names": self.agent_executor.tools_names,
#     852             "tools": self.agent_executor.tools_description,
#     853             "ask_for_human_input": task.human_input,
#     854         }
#     855     ),
#     856 )
#     857 return result["output"]
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agents/crew_agent_executor.py:214, in CrewAgentExecutor.invoke(self, inputs)
#     211 self.ask_for_human_input = bool(inputs.get("ask_for_human_input", False))
#     213 try:
# --> 214     formatted_answer = self._invoke_loop()
#     215 except AssertionError:
#     216     if self.agent.verbose:
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agents/crew_agent_executor.py:311, in CrewAgentExecutor._invoke_loop(self)
#     308 if use_native_tools:
#     309     return self._invoke_loop_native_tools()
# --> 311 return self._invoke_loop_react()
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agents/crew_agent_executor.py:437, in CrewAgentExecutor._invoke_loop_react(self)
#     435         continue
#     436     handle_unknown_error(PRINTER, e, verbose=self.agent.verbose)
# --> 437     raise e
#     438 finally:
#     439     self.iterations += 1
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/agents/crew_agent_executor.py:339, in CrewAgentExecutor._invoke_loop_react(self)
#     335     break
#     337 enforce_rpm_limit(self.request_within_rpm_limit)
# --> 339 answer = get_llm_response(
#     340     llm=cast("BaseLLM", self.llm),
#     341     messages=self.messages,
#     342     callbacks=self.callbacks,
#     343     printer=PRINTER,
#     344     from_task=self.task,
#     345     from_agent=self.agent,
#     346     response_model=self.response_model,
#     347     executor_context=self,
#     348     verbose=self.agent.verbose,
#     349 )
#     350 if self.response_model is not None:
#     351     try:
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/utilities/agent_utils.py:473, in get_llm_response(llm, messages, callbacks, printer, tools, available_functions, from_task, from_agent, response_model, executor_context, verbose)
#     463     answer = llm.call(
#     464         messages,
#     465         tools=tools,
#    (...)    470         response_model=response_model,
#     471     )
#     472 except Exception as e:
# --> 473     raise e
#     475 return _validate_and_finalize_llm_response(
#     476     answer, executor_context, printer, verbose=verbose
#     477 )
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/utilities/agent_utils.py:463, in get_llm_response(llm, messages, callbacks, printer, tools, available_functions, from_task, from_agent, response_model, executor_context, verbose)
#     460 messages = _prepare_llm_call(executor_context, messages, printer, verbose=verbose)
#     462 try:
# --> 463     answer = llm.call(
#     464         messages,
#     465         tools=tools,
#     466         callbacks=callbacks,
#     467         available_functions=available_functions,
#     468         from_task=from_task,
#     469         from_agent=from_agent,
#     470         response_model=response_model,
#     471     )
#     472 except Exception as e:
#     473     raise e
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/llms/providers/openai/completion.py:443, in OpenAICompletion.call(self, messages, tools, callbacks, available_functions, from_task, from_agent, response_model)
#     433     if self.api == "responses":
#     434         return self._call_responses(
#     435             messages=formatted_messages,
#     436             tools=tools,
#    (...)    440             response_model=response_model,
#     441         )
# --> 443     return self._call_completions(
#     444         messages=formatted_messages,
#     445         tools=tools,
#     446         available_functions=available_functions,
#     447         from_task=from_task,
#     448         from_agent=from_agent,
#     449         response_model=response_model,
#     450     )
#     452 except Exception as e:
#     453     error_msg = f"OpenAI API call failed: {e!s}"
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/llms/providers/openai/completion.py:483, in OpenAICompletion._call_completions(self, messages, tools, available_functions, from_task, from_agent, response_model)
#     474 if self.stream:
#     475     return self._handle_streaming_completion(
#     476         params=completion_params,
#     477         available_functions=available_functions,
#    (...)    480         response_model=response_model,
#     481     )
# --> 483 return self._handle_completion(
#     484     params=completion_params,
#     485     available_functions=available_functions,
#     486     from_task=from_task,
#     487     from_agent=from_agent,
#     488     response_model=response_model,
#     489 )
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/llms/providers/openai/completion.py:1745, in OpenAICompletion._handle_completion(self, params, available_functions, from_task, from_agent, response_model)
#    1741     logging.error(error_msg)
#    1742     self._emit_call_failed_event(
#    1743         error=error_msg, from_task=from_task, from_agent=from_agent
#    1744     )
# -> 1745     raise e from e
#    1747 return content
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/crewai/llms/providers/openai/completion.py:1636, in OpenAICompletion._handle_completion(self, params, available_functions, from_task, from_agent, response_model)
#    1626         self._emit_call_completed_event(
#    1627             response=parsed_object.model_dump_json(),
#    1628             call_type=LLMCallType.LLM_CALL,
#    (...)   1632             usage=usage,
#    1633         )
#    1634         return parsed_object
# -> 1636 response: ChatCompletion = self._get_sync_client().chat.completions.create(
#    1637     **params
#    1638 )
#    1640 usage = self._extract_openai_token_usage(response)
#    1642 self._track_token_usage_internal(usage)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/openai/resources/chat/completions/completions.py:1211, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1164 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1165 def create(
#    1166     self,
#    (...)   1208     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1209 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1210     validate_response_format(response_format)
# -> 1211     return self._post(
#    1212         "/chat/completions",
#    1213         body=maybe_transform(
#    1214             {
#    1215                 "messages": messages,
#    1216                 "model": model,
#    1217                 "audio": audio,
#    1218                 "frequency_penalty": frequency_penalty,
#    1219                 "function_call": function_call,
#    1220                 "functions": functions,
#    1221                 "logit_bias": logit_bias,
#    1222                 "logprobs": logprobs,
#    1223                 "max_completion_tokens": max_completion_tokens,
#    1224                 "max_tokens": max_tokens,
#    1225                 "metadata": metadata,
#    1226                 "modalities": modalities,
#    1227                 "n": n,
#    1228                 "parallel_tool_calls": parallel_tool_calls,
#    1229                 "prediction": prediction,
#    1230                 "presence_penalty": presence_penalty,
#    1231                 "prompt_cache_key": prompt_cache_key,
#    1232                 "prompt_cache_retention": prompt_cache_retention,
#    1233                 "reasoning_effort": reasoning_effort,
#    1234                 "response_format": response_format,
#    1235                 "safety_identifier": safety_identifier,
#    1236                 "seed": seed,
#    1237                 "service_tier": service_tier,
#    1238                 "stop": stop,
#    1239                 "store": store,
#    1240                 "stream": stream,
#    1241                 "stream_options": stream_options,
#    1242                 "temperature": temperature,
#    1243                 "tool_choice": tool_choice,
#    1244                 "tools": tools,
#    1245                 "top_logprobs": top_logprobs,
#    1246                 "top_p": top_p,
#    1247                 "user": user,
#    1248                 "verbosity": verbosity,
#    1249                 "web_search_options": web_search_options,
#    1250             },
#    1251             completion_create_params.CompletionCreateParamsStreaming
#    1252             if stream
#    1253             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1254         ),
#    1255         options=make_request_options(
#    1256             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1257         ),
#    1258         cast_to=ChatCompletion,
#    1259         stream=stream or False,
#    1260         stream_cls=Stream[ChatCompletionChunk],
#    1261     )
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/openai/_base_client.py:1297, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1288     warnings.warn(
#    1289         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1290         "Please pass raw bytes via the `content` parameter instead.",
#    1291         DeprecationWarning,
#    1292         stacklevel=2,
#    1293     )
#    1294 opts = FinalRequestOptions.construct(
#    1295     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1296 )
# -> 1297 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Documents/agents/agent-jupyter/venv/lib/python3.13/site-packages/openai/_base_client.py:1070, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1067             err.response.read()
#    1069         log.debug("Re-raising status error")
# -> 1070         raise self._make_status_error_from_response(err.response) from None
#    1072     break
#    1074 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'error': {'message': 'The supported API model names are deepseek-v4-pro or deepseek-v4-flash, but you passed gpt-4o-mini.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_request_error'}}

# %%
from IPython.display import Markdown
Markdown(result.raw)
